# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('DS1_C4_S4_Car_Prices_Data_Challenge (1).csv')
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %% [markdown]
# ### Display 5 low priced cars from 2014

# %%
cars1=data[(data.year==2014)]
cars1
# Out:
#         year       make                model                       trim  \
# 2       2014        BMW             3 Series                 328i SULEV
# 4       2014        BMW  6 Series Gran Coupe                       650i
# 6       2014        BMW                   M5                       Base
# 7       2014  Chevrolet                Cruze                        1LT
# 8       2014       Audi                   A4  2.0T Premium Plus quattro
# ...      ...        ...                  ...                        ...
# 558814  2014      Dodge              Charger                         SE
# 558820  2014      Dodge              Charger                         SE
# 558826  2014       Jeep       Grand Cherokee                    Limited
# 558827  2014       Jeep       Grand Cherokee                     Laredo
# 558836  2014       Ford                F-150                        XLT
#
#              body transmission                vin state  condition  odometer  \
# ...

# %%
cars1a=cars1.groupby(by=['year','model'])['sellingprice'].mean()
cars1a
# Out:
# year  model
# 2014  1500        26381.699301
#       2 Series    37497.368421
#       200         11840.521064
#       2500        38420.322940
#       3 Series    32772.956522
#                       ...
#       regal       17366.666667
#       routan      21400.000000
#       tC          15791.228070
#       xB          15015.384615
#       xD          13027.083333
# Name: sellingprice, Length: 325, dtype: float64

# %%
cars1a.sort_values(ascending=True)
# Out:
# year  model
# 2014  Spark            8380.871212
#       fortwo           8620.000000
#       Mirage           8876.785714
#       Versa            9662.449794
#       Mazda2          10101.898734
#                          ...
#       Range Rover     99911.111111
#       RS 7           102225.000000
#       G-Class        109138.235294
#       Flying Spur    154000.000000
#       i8             154222.222222
# Name: sellingprice, Length: 325, dtype: float64

# %%
print("The lowest selling models are Spark, Fortwo, Mirage, Versa, and Mazda2")
# Out:
# The lowest selling models are Spark, Fortwo, Mirage, Versa, and Mazda2

# %% [markdown]
# Compare selling price of BMW's from 2010 to 2015

# %%
cars2=data[(data.condition > 4.5)& (data.make=='BMW')& (data.year==2010)]
cars2
# Out:
#         year make                  model          trim         body  \
# 43927   2010  BMW               3 Series          328i        Coupe
# 70751   2010  BMW               3 Series          328i        Sedan
# 114558  2010  BMW               6 Series          650i  Convertible
# 114559  2010  BMW               3 Series   328i xDrive        Sedan
# 126368  2010  BMW                     M3          Base        Coupe
# 135141  2010  BMW                     X5     xDrive35d          SUV
# 153657  2010  BMW               3 Series          335d        Sedan
# 153661  2010  BMW               7 Series   750i xDrive        Sedan
# 194514  2010  BMW               5 Series          535i        Sedan
# 226562  2010  BMW               7 Series         750Li        Sedan
# 251236  2010  BMW               3 Series          328i  Convertible
# 251237  2010  BMW                     X3     xDrive30i          SUV
# 258240  2010  BMW               5 Series          528i        Sedan
# ...

# %%
avg2010 = cars2.sellingprice.mean()
avg2010
# Out:
# 23572.222222222223

# %%
cars2a=data[(data.condition > 4.5)& (data.make=='BMW')& (data.year==2015)]
cars2a
# Out:
#         year make     model       trim   body transmission                vin  \
# 7876    2015  BMW        M4       Base  Coupe    automatic  wbs3r9c53fk329392
# 43585   2015  BMW        X1  xDrive28i    SUV    automatic  wbavl1c56fvy26418
# 56898   2015  BMW        X1  xDrive28i    SUV    automatic  wbavl1c56fvy24992
# 56900   2015  BMW        X1  xDrive35i    SUV    automatic  wbavm5c51fvv93813
# 56902   2015  BMW        X1  xDrive35i    SUV    automatic  wbavm5c59fvv94093
# ...      ...  ...       ...        ...    ...          ...                ...
# 548650  2015  BMW        X5  xDrive50i    suv    automatic  5uxkr6c53f0j76217
# 548652  2015  BMW  2 Series      M235i  coupe       manual  wba1j7c57fv288951
# 549682  2015  BMW  3 Series       320i  sedan    automatic  wba3b1c51fk136801
# 549683  2015  BMW  3 Series       328i  sedan    automatic  wba3a5c56ff606212
# 557843  2015  BMW        M4       Base  coupe    automatic  wbs3r9c52fk329996
#
# ...

# %%
avg2015 = cars2a.sellingprice.mean()
avg2015
# Out:
# 42994.68599033816

# %%
#Percentages are compared? In what way?

# %%
increase=avg2015-avg2010
increase
# Out:
# 19422.46376811594

# %%
percent_increase=increase/avg2010*100
percent_increase
# Out:
# 82.39555687628727

# %%
print("The percentage of cars increased by 82%")
# Out:
# The percentage of cars increased by 82%

# %% [markdown]
# ### Determine the difference between average wholesale prices of cars with black and gray interiors

# %%
black=data[(data.color=='black')]
black
# Out:
#         year           make           model                   trim      body  \
# 6       2014            BMW              M5                   Base     Sedan
# 7       2014      Chevrolet           Cruze                    1LT     Sedan
# 10      2014           Audi              A6  3.0T Prestige quattro     Sedan
# 15      2015         Nissan          Altima                  2.5 S     Sedan
# 18      2014      Chevrolet          Camaro                     LS     Coupe
# ...      ...            ...             ...                    ...       ...
# 558807  2014  Mercedes-Benz         E-Class         E63 AMG 4MATIC     Sedan
# 558813  2006       Chrysler             300                      C     sedan
# 558816  2013  Mercedes-Benz         G-Class                G63 AMG       suv
# 558818  2013      Chevrolet  Silverado 1500                     LT  crew cab
# 558834  2012            BMW              X5              xDrive35d       SUV
#
# ...

# %%
avgblack= black.sellingprice.mean()
avgblack
# Out:
# 15508.880891019518

# %%
gray=data[(data.color=='gray')]
gray
# Out:
#         year     make                model              trim       body  \
# 2       2014      BMW             3 Series        328i SULEV      Sedan
# 4       2014      BMW  6 Series Gran Coupe              650i      Sedan
# 5       2015   Nissan               Altima             2.5 S      Sedan
# 23      2015     Audi                   A3  1.8 TFSI Premium      Sedan
# 28      2014      BMW                   X5         sDrive35i        SUV
# ...      ...      ...                  ...               ...        ...
# 558810  2013    Honda                Civic           LX PZEV      Sedan
# 558826  2014     Jeep       Grand Cherokee           Limited        SUV
# 558827  2014     Jeep       Grand Cherokee            Laredo        SUV
# 558829  2012  Hyundai              Elantra           Limited      Sedan
# 558836  2014     Ford                F-150               XLT  SuperCrew
#
#        transmission                vin state  condition  odometer color  \
# ...

# %%
avggray= gray.sellingprice.mean()
avggray
# Out:
# 13951.159594496741

# %%
difference=avgblack-avggray
print("The difference of wholesale prices between black and gray interiors is", difference)
# Out:
# The difference of wholesale prices between black and gray interiors is 1557.7212965227773

# %% [markdown]
# ### Find models manufactured between 2013 and 2015

# %%
cars4=data[(data.year >=2013) & (data.year <= 2015)]
cars4
# Out:
#         year    make                model        trim       body transmission  \
# 0       2015     Kia              Sorento          LX        SUV    automatic
# 1       2015     Kia              Sorento          LX        SUV    automatic
# 2       2014     BMW             3 Series  328i SULEV      Sedan    automatic
# 3       2015   Volvo                  S60          T5      Sedan    automatic
# 4       2014     BMW  6 Series Gran Coupe        650i      Sedan    automatic
# ...      ...     ...                  ...         ...        ...          ...
# 558826  2014    Jeep       Grand Cherokee     Limited        SUV    automatic
# 558827  2014    Jeep       Grand Cherokee      Laredo        SUV    automatic
# 558832  2015     Kia                 K900      Luxury      Sedan          NaN
# 558835  2015  Nissan               Altima       2.5 S      sedan    automatic
# 558836  2014    Ford                F-150         XLT  SuperCrew    automatic
#
# ...

# %%
pd.crosstab(cars4.make, cars4.color, rownames=['Manufacturer'], colnames=['Color'], margins=True)
# Out:
# Color          beige  black   blue  brown  burgundy  charcoal  gold   gray  \
# Manufacturer
# Acura              0    170     19      5        20         2     0    107
# Audi               2    402     78     10         1         0     1    181
# BMW               34   1235    252     99         1         1     8    710
# Bentley            0      5      3      0         0         0     0      3
# Buick             21    157     55     25        12         1    19    189
# Cadillac          55    298     36     12         2         0    50     85
# Chevrolet        421   3570   1582    153       167        36   354   2933
# Chrysler         175   1599    848     56       232        18   334   1343
# Dodge            129   2412   1722     15       100        40   311   2304
# FIAT               7    123     37     12         0         9     0     91
# Ford              55   7102   2209    550       444        12    70   5076
# ...

# %%
print("The color of cars people drive the most is white.")
# Out:
# The color of cars people drive the most is white.

# %% [markdown]
# ### Find the Total Sale of SUV's on Fri 12/9 and Thur 1/15. Find the % increase or decrease during this period.

# %%
from datetime import date

# %%
data5=pd.DataFrame({
'body':['SUV'],
'saledate':['Thu Jan 15, 2015, 04:30:00 GMT-0800 (PST)']    
})
data['saledate']=pd.to_datetime(data['saledate'])
data
# Out:
#   body                  saledate
# 0  SUV 2014-12-19 09:00:00+08:00

# %%
data5a=pd.DataFrame({
'body':['SUV'],
'saledate':['Fri Dec 19, 2014, 09:00:00 GMT-0800']    
})
data['saledate']=pd.to_datetime(data['saledate'])
data
# Out:
#   body                  saledate
# 0  SUV 2014-12-19 09:00:00+08:00

# %% [markdown]
# ###  Add new column "Discounted Price" next to "Selling Price" and calculate 10% for Chevy & Ford and 20% for all other car manuafcturers.

# %%
import numpy as np
data.insert(14, 'discounted_price',np.nan)
data.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca        4.5    1331.0   gray    black
# 3  yv1612tb4f1310987    ca        4.1   14282.0  white    black
# 4  wba6b2c57ed129731    ca        4.3    2641.0   gray    black
#
#                                    seller    mmr  discounted_price  \
# 0                 kia motors america, inc  20500               NaN
# ...

# %%
data6=data[(data.make=='Chevrolet')]
data6
# Out:
#         year       make           model trim         body transmission  \
# 7       2014  Chevrolet           Cruze  1LT        Sedan    automatic
# 9       2014  Chevrolet          Camaro   LT  Convertible    automatic
# 14      2014  Chevrolet           Cruze  2LT        Sedan    automatic
# 18      2014  Chevrolet          Camaro   LS        Coupe    automatic
# 20      2015  Chevrolet          Impala  LTZ        Sedan    automatic
# ...      ...        ...             ...  ...          ...          ...
# 558764  2002  Chevrolet          Blazer   LS          suv    automatic
# 558788  2014  Chevrolet  Silverado 1500   LT     crew cab          NaN
# 558792  2011  Chevrolet             HHR   LT        Wagon    automatic
# 558818  2013  Chevrolet  Silverado 1500   LT     crew cab    automatic
# 558823  2012  Chevrolet  Silverado 1500   LT     Crew Cab    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
#Next Steps: create seperate data frames for each discount then merge together

# %%
data7=data[(data.make=='Ford')]
data7
# Out:
#         year  make           model                 trim       body  \
# 12      2015  Ford          Fusion                   SE      Sedan
# 94      2015  Ford          Fusion                   SE      Sedan
# 305     2014  Ford          Escape             Titanium        SUV
# 938     2012  Ford  E-Series Wagon  E-350 Super Duty XL        Van
# 939     2012  Ford          Escape              Limited        SUV
# ...      ...   ...             ...                  ...        ...
# 558799  2012  Ford           Focus                   SE  Hatchback
# 558803  2007  Ford    Five Hundred                  SEL      sedan
# 558817  2012  Ford            Flex                  SEL      Wagon
# 558821  2012  Ford          Escape                  XLT        SUV
# 558836  2014  Ford           F-150                  XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 12        automatic  3fa6p0hdxfr145753    ca        2.0    5559.0  white
# ...

# %%
D8 = pd.concat([data6,data7],ignore_index=True)
D8
# Out:
#         year       make         model trim         body transmission  \
# 0       2014  Chevrolet         Cruze  1LT        Sedan    automatic
# 1       2014  Chevrolet        Camaro   LT  Convertible    automatic
# 2       2014  Chevrolet         Cruze  2LT        Sedan    automatic
# 3       2014  Chevrolet        Camaro   LS        Coupe    automatic
# 4       2015  Chevrolet        Impala  LTZ        Sedan    automatic
# ...      ...        ...           ...  ...          ...          ...
# 153746  2012       Ford         Focus   SE    Hatchback    automatic
# 153747  2007       Ford  Five Hundred  SEL        sedan    automatic
# 153748  2012       Ford          Flex  SEL        Wagon    automatic
# 153749  2012       Ford        Escape  XLT          SUV    automatic
# 153750  2014       Ford         F-150  XLT    SuperCrew    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...
