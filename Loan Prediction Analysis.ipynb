# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('DS1_C4_S3_Loan_Data_Practice.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ### Display Loan ID and Gender of incomes <6000 and loan amounts> 200,000

# %%
list1 = data[(data.ApplicantIncome < 6000) & (data.LoanAmount > 200)]
list1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 21   LP001046    Male     Yes          1      Graduate            No
# 30   LP001091    Male     Yes          1      Graduate           Yes
# 65   LP001225    Male     Yes          0      Graduate            No
# 108  LP001379    Male     Yes          2      Graduate            No
# 135  LP001488    Male     Yes         3+      Graduate            No
# 159  LP001552    Male     Yes          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 236  LP001786    Male     Yes          0      Graduate            No
# 250  LP001835    Male     Yes          0  Not Graduate            No
# 253  LP001843    Male     Yes          1  Not Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# 276  LP001903    Male     Yes          0      Graduate            No
# ...

# %% [markdown]
# ### Find the difference  and percentage of number of customers living in urban and suburban areas

# %%
urban_list=data[(data.Property_Area=='Urban')]
urban_list
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 600  LP002949  Female      No         3+      Graduate           Yes
# 602  LP002953    Male     Yes         3+      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
semiurban_list=data[(data.Property_Area=='Semiurban')]
semiurban_list
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 7    LP001014    Male     Yes         3+      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 22   LP001047    Male     Yes          0  Not Graduate            No
# 24   LP001052    Male     Yes          1      Graduate           Yes
# 25   LP001066    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 592  LP002933    Male      No         3+      Graduate           Yes
# 597  LP002943    Male      No          1      Graduate            No
# 604  LP002959  Female     Yes          1      Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
urban_sum = urban_list.ApplicantIncome.sum()
print("Sum of applicant's income who have property in urban area is ",urban_sum)
# Out:
# Sum of applicant's income who have property in urban area is  1090446

# %%
semiurban_sum = semiurban_list.ApplicantIncome.sum()
print("Sum of applicant's income who have property in urban area is ",semiurban_sum)
# Out:
# Sum of applicant's income who have property in urban area is  1233097

# %% [markdown]
# ### Record of top 5 customers with highest income and approved loans

# %%
data.shape
# Out:
# (614, 13)

# %%
approved=data[data.Loan_Status=='Y']
approved
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sort = approved.sort_values('ApplicantIncome', ascending=False)
sort
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 333  LP002101    Male     Yes          0      Graduate            No
# 171  LP001585    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 185  LP001640    Male     Yes          0      Graduate           Yes
# 443  LP002422    Male      No          1      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 530  LP002717    Male     Yes          0      Graduate            No
# 418  LP002345    Male     Yes          0      Graduate            No
# 188  LP001644    Male     Yes          0      Graduate           Yes
# 500  LP002603  Female      No          0      Graduate            No
# 468  LP002502  Female     Yes          2  Not Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sort.iloc[:5, ]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 333  LP002101   Male     Yes          0  Graduate            No
# 171  LP001585   Male     Yes         3+  Graduate            No
# 155  LP001536   Male     Yes         3+  Graduate            No
# 185  LP001640   Male     Yes          0  Graduate           Yes
# 443  LP002422   Male      No          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 333            63337                0.0         490               180
# 171            51763                0.0         700               300
# 155            39999                0.0         600               180
# 185            39147             4750.0         120               360
# 443            37719                0.0         152               360
#
#      Credit_History Property_Area Loan_Status
# 333               1         Urban           Y
# 171               1         Urban           Y
# ...

# %% [markdown]
# ### Display incomes and loan amounts for females w/2 dependents

# %%
females=data[(data.Gender=='Female') &(data.Dependents=='2')& (data.LoanAmount>1) & (data.ApplicantIncome>1)]
females
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 29   LP001087  Female      No          2      Graduate           Yes
# 82   LP001267  Female     Yes          2      Graduate            No
# 146  LP001516  Female     Yes          2      Graduate            No
# 219  LP001734  Female     Yes          2      Graduate            No
# 251  LP001836  Female      No          2      Graduate            No
# 293  LP001945  Female      No          2      Graduate            No
# 468  LP002502  Female     Yes          2  Not Graduate           Yes
# 516  LP002670  Female     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 29              3750             2083.0         120               360
# 82              1378             1881.0         167               360
# 146            14866                0.0          70               360
# ...

# %% [markdown]
# ### Display females with loan > 200 and replace Loan Amount Term value with 180

# %%
females1=data[(data.Gender=='Female') & (data.LoanAmount>200)]
females1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 119  LP001422  Female      No          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 210  LP001708  Female      No          0      Graduate            No
# 233  LP001776  Female      No          0      Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 600  LP002949  Female      No         3+      Graduate           Yes
# 604  LP002959  Female     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 54             11500                0.0         286               360
# ...

# %%
females1['Loan_Amount_Term'] = females1['Loan_Amount_Term'].replace([200],180)
females1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 119  LP001422  Female      No          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 210  LP001708  Female      No          0      Graduate            No
# 233  LP001776  Female      No          0      Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 600  LP002949  Female      No         3+      Graduate           Yes
# 604  LP002959  Female     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 54             11500                0.0         286               360
# ...

# %% [markdown]
# ### Rename Loan Amount Term, replace 12 and 36 with 60 as a value

# %%
data = data.rename(columns={"Loan_Amount_Term": "LoanAmountTerm"})
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0               5849                0.0         146             360
# ...

# %%
data['LoanAmountTerm'] = data['LoanAmountTerm'].replace([12],60)
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0               5849                0.0         146             360
# ...

# %%
data['LoanAmountTerm'] = data['LoanAmountTerm'].replace([36],60)
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0               5849                0.0         146             360
# ...

# %% [markdown]
# ### Display income of self-employed graduates increase credit to twice their income

# %%
graduates=data[(data.Self_Employed=='Yes') &(data.ApplicantIncome > 10)& (data.Education=='Graduate')]
graduates
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 5    LP001011    Male     Yes          2  Graduate           Yes
# 11   LP001027    Male     Yes          2  Graduate           Yes
# 19   LP001041    Male     Yes          0  Graduate           Yes
# 24   LP001052    Male     Yes          1  Graduate           Yes
# ..        ...     ...     ...        ...       ...           ...
# 592  LP002933    Male      No         3+  Graduate           Yes
# 594  LP002938    Male     Yes          0  Graduate           Yes
# 598  LP002945    Male     Yes          0  Graduate           Yes
# 600  LP002949  Female      No         3+  Graduate           Yes
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2               3000                0.0          66               360
# ...

# %%
graduates.loc[1:82]['ApplicantIncome']
# Out:
# 2      3000
# 5      5417
# 11     2500
# 19     2600
# 24     3717
# 25     9560
# 29     3750
# 30     4166
# 32     4692
# 54    11500
# 74     5266
# 77     1000
# 81     2395
# Name: ApplicantIncome, dtype: int64

# %%
graduates2=(graduates.ApplicantIncome*2)
graduates2
# Out:
# 2       6000
# 5      10834
# 11      5000
# 19      5200
# 24      7434
#        ...
# 592    18714
# 594    32240
# 598    19926
# 600      832
# 613     9166
# Name: ApplicantIncome, Length: 82, dtype: int64

# %%
graduates2
# Out:
# 2       6000
# 5      10834
# 11      5000
# 19      5200
# 24      7434
#        ...
# 592    18714
# 594    32240
# 598    19926
# 600      832
# 613     9166
# Name: ApplicantIncome, Length: 82, dtype: int64

# %%
graduates = pd.concat([graduates,graduates2],axis=1)
graduates
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 5    LP001011    Male     Yes          2  Graduate           Yes
# 11   LP001027    Male     Yes          2  Graduate           Yes
# 19   LP001041    Male     Yes          0  Graduate           Yes
# 24   LP001052    Male     Yes          1  Graduate           Yes
# ..        ...     ...     ...        ...       ...           ...
# 592  LP002933    Male      No         3+  Graduate           Yes
# 594  LP002938    Male     Yes          0  Graduate           Yes
# 598  LP002945    Male     Yes          0  Graduate           Yes
# 600  LP002949  Female      No         3+  Graduate           Yes
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2               3000                0.0          66               360
# ...

# %% [markdown]
# ### Delete records of customers with more than 3 dependents, 0 credit history, and not graduates

# %%
z=data[(data.Credit_History==0) & (data.Dependents=='3+')& (data.Education=='Graduate')]
z
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 7    LP001014    Male     Yes         3+  Graduate            No
# 78   LP001263    Male     Yes         3+  Graduate            No
# 155  LP001536    Male     Yes         3+  Graduate            No
# 177  LP001610    Male     Yes         3+  Graduate            No
# 211  LP001711    Male     Yes         3+  Graduate            No
# 267  LP001882    Male     Yes         3+  Graduate            No
# 409  LP002317    Male     Yes         3+  Graduate            No
# 567  LP002837    Male     Yes         3+  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 7               3036             2504.0         158               360
# 78              3167             4000.0         180               300
# 155            39999                0.0         600               180
# ...

# %%
z.drop(z.columns[[3,4,10]], axis=1, inplace=True)
z
# Out:
#       Loan_ID  Gender Married Self_Employed  ApplicantIncome  \
# 7    LP001014    Male     Yes            No             3036
# 78   LP001263    Male     Yes            No             3167
# 155  LP001536    Male     Yes            No            39999
# 177  LP001610    Male     Yes            No             5516
# 211  LP001711    Male     Yes            No             3430
# 267  LP001882    Male     Yes            No             4333
# 409  LP002317    Male     Yes            No            81000
# 567  LP002837    Male     Yes            No             3400
# 600  LP002949  Female      No           Yes              416
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# 7               2504.0         158               360     Semiurban           N
# 78              4000.0         180               300     Semiurban           N
# 155                0.0         600               180     Semiurban           Y
# ...

# %%
list9=data[(data.Education=='Graduate')]
list9
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001002    Male      No          0  Graduate            No
# 1    LP001003    Male     Yes          1  Graduate            No
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 4    LP001008    Male      No          0  Graduate            No
# 5    LP001011    Male     Yes          2  Graduate           Yes
# ..        ...     ...     ...        ...       ...           ...
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
list10=data[(data.Education=='Not Graduate')]
list10
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 6    LP001013   Male     Yes          0  Not Graduate            No
# 16   LP001034   Male      No          1  Not Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# 20   LP001043   Male     Yes          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 595  LP002940   Male      No          0  Not Graduate            No
# 596  LP002941   Male     Yes          2  Not Graduate           Yes
# 601  LP002950   Male     Yes          0  Not Graduate           Yes
# 605  LP002960   Male     Yes          0  Not Graduate            No
# 607  LP002964   Male     Yes          2  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 3               2583             2358.0         120               360
# ...

# %%
avginc = list9.ApplicantIncome.mean()
avginc
# Out:
# 5857.433333333333

# %%
avginc = list10.ApplicantIncome.mean()
avginc
# Out:
# 3777.283582089552
